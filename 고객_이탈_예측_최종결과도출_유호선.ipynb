# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
telco = pd.read_csv('telco.csv')

# %%
# R에서 결측치 확인 코드
# miss_var_summary(telco)

# %%
# import pandas as pd
# from plotnine import ggplot, aes, geom_bar, geom_text, geom_label, position_stack, theme
# from plotnine.scales import percent
# from plotnine.facets import facet_wrap

# # Assuming you have already defined a function multiplot to arrange plots, as it's not standard in plotnine

# # Assuming DF is your DataFrame

# g1 = (
#     ggplot(telco, aes(x='Gender')) +
#     geom_bar(aes(fill='Churn'), position='stack', width=0.5) +
#     geom_text(aes(fill='Churn', label='stat(count)'),
#               position=position_stack(0.5)) +
#     geom_label(aes(label='stat(count)', y='stat(count)'),
#                position=position_stack(vjust=0))
# )

# g2 = (
#     ggplot(telco, aes(x='Gender', fill='Churn')) +
#     geom_bar(position='stack') +
#     geom_text(aes(label='stat(prop)*100'),
#               stat='count', position=position_stack(0.5)) +
#     theme(legend_position='none')
# )

# g3 = (
#     ggplot(telco, aes(x='Gender', fill='Churn')) +
#     geom_bar(position='stack') +
#     geom_text(aes(label='stat(count)/sum(stat(count))'),
#               position=position_stack(0.5)) +
#     theme(legend_position='none')
# )

# # Assuming multiplot is a function you have defined elsewhere to arrange plots
# multiplot(g1, g2, g3)

# %%
telco['Churn'].value_counts()
# Out:
# No     5174
# Yes    1869
# Name: Churn, dtype: int64

# %%
# sns.distplot(telco['Churn'])
telco.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
telco.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
#  16  PaperlessBilling  7043 non-null   object
#  17  PaymentMethod     7043 non-null   object
#  18  MonthlyCharges    7043 non-null   float64
#  19  TotalCharges      7043 non-null   object
#  20  Churn             7043 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.1+ MB

# %%
# telco['TotalCharges'] = telco['TotalCharges'].astype('float')
telco['TotalCharges'] = telco['TotalCharges'].replace(' ',np.nan)

# %%
telco.dropna(inplace=True)
telco.drop('customerID', axis=1, inplace=True)

# %%
telco['TotalCharges'] = telco['TotalCharges'].astype(float)

# %%
telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   object
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   object
#  3   Dependents        7032 non-null   object
#  4   tenure            7032 non-null   int64
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  Contract          7032 non-null   object
#  15  PaperlessBilling  7032 non-null   object
#  16  PaymentMethod     7032 non-null   object
#  17  MonthlyCharges    7032 non-null   float64
#  18  TotalCharges      7032 non-null   float64
#  19  Churn             7032 non-null   object
# dtypes: float64(2), int64(2), object(16)
# memory usage: 1.1+ MB

# %%
telco.loc[telco.Churn == 'No', 'Churn'] == 0
telco.loc[telco.Churn == 'Yes', 'Churn'] == 1
# telco.Churn = telco.Churn.astype(int)
# telco['Churn'] = telco.replace[{}]
telco['Churn'] = telco['Churn'].replace({'No':0, 'Yes':1})

# %%
telco['Churn'].value_counts()
# Out:
# 0    5163
# 1    1869
# Name: Churn, dtype: int64

# %%
import math

# %%
cols = telco.columns.tolist()

# %%
cols
# Out:
# ['gender',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'tenure',
#  'PhoneService',
#  'MultipleLines',
#  'InternetService',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'Contract',
#  'PaperlessBilling',
#  'PaymentMethod',
#  'MonthlyCharges',
#  'TotalCharges',
#  'Churn']

# %%
somecols = ['tenure', 'MonthlyCharges', 'TotalCharges']
for i in somecols:
    cols.remove(i)

f, axes = plt.subplots(math.ceil(len(cols)/4),4, figsize=(25,25))
for col, ax in zip(cols, axes.ravel()):
        data = telco[col].value_counts().values.tolist()
        labels = telco[col].value_counts().index.tolist()
        ax.pie(data,autopct='%0.2f%%')
        ax.set_title(col)
        ax.legend(labels,loc='best')

# %%
colormap = plt.cm.RdBu
plt.figure(figsize=(14,12))
plt.title('Pearson Correlation of Features', y=1.05, size=15)
sns.heatmap(telco.corr(),linewidths=0.1, vmax=1.0,square=True, cmap=colormap, linecolor='white', annot=True)
# Out:
# <ipython-input-17-1d3a3472a93a>:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(telco.corr(),linewidths=0.1, vmax=1.0,square=True, cmap=colormap, linecolor='white', annot=True)
# <Axes: title={'center': 'Pearson Correlation of Features'}>

# %%
telco.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges  TotalCharges        Churn
# count    7032.000000  7032.000000     7032.000000   7032.000000  7032.000000
# mean        0.162400    32.421786       64.798208   2283.300441     0.265785
# std         0.368844    24.545260       30.085974   2266.771362     0.441782
# min         0.000000     1.000000       18.250000     18.800000     0.000000
# 25%         0.000000     9.000000       35.587500    401.450000     0.000000
# 50%         0.000000    29.000000       70.350000   1397.475000     0.000000
# 75%         0.000000    55.000000       89.862500   3794.737500     1.000000
# max         1.000000    72.000000      118.750000   8684.800000     1.000000

# %%
telco['MonthlyCharges'].value_counts()
# Out:
# 20.05     61
# 19.90     44
# 19.95     44
# 19.85     44
# 19.65     43
#           ..
# 23.65      1
# 114.70     1
# 43.65      1
# 87.80      1
# 78.70      1
# Name: MonthlyCharges, Length: 1584, dtype: int64

# %%
sns.distplot(telco['MonthlyCharges'])
# Out:
# <ipython-input-20-089b2c65c3cf>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(telco['MonthlyCharges'])
# <Axes: xlabel='MonthlyCharges', ylabel='Density'>

# %%
sns.distplot(telco['tenure'])
# Out:
# <ipython-input-21-8c9b2309891c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(telco['tenure'])
# <Axes: xlabel='tenure', ylabel='Density'>

# %%
sns.pairplot(telco)

# %%
telco_tenure = telco.tenure.value_counts().sort_index()
x = telco_tenure.index
y1 = telco_tenure.values
y2 = telco.groupby('tenure').Churn.mean().values

# %%
telco_tenure
# Out:
# 1     613
# 2     238
# 3     200
# 4     176
# 5     133
#      ...
# 68    100
# 69     95
# 70    119
# 71    170
# 72    362
# Name: tenure, Length: 72, dtype: int64

# %%
fig, ax1 = plt.subplots(figsize=(15,8))
ax2 = ax1.twinx()

ax1.plot(x,y1,'g-')
ax2.plot(x,y2,'b-')

ax1.set_xticks(range(0,80,2))
ax1.set_ylabel('count', color='g')
ax2.set_ylabel('churn rate', color='b')
ax2.set_ylim((0,1))
# Out:
# (0.0, 1.0)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
tenuer = np.array(telco.tenure).reshape(-1,1)
scaler = MinMaxScaler()
sample_a = scaler.fit_transform(tenuer)
telco['tenure'] = sample_a

# %%
telco['tenure']
# Out:
# 0       0.000000
# 1       0.464789
# 2       0.014085
# 3       0.619718
# 4       0.014085
#           ...
# 7038    0.323944
# 7039    1.000000
# 7040    0.140845
# 7041    0.042254
# 7042    0.915493
# Name: tenure, Length: 7032, dtype: float64

# %%
#Monthly Charges : 정규화
monthly = np.array(telco.MonthlyCharges).reshape(-1,1)
scaler = MinMaxScaler()
monthly_a = scaler.fit_transform(monthly)
telco['MonthlyCharges'] = monthly_a

# %%
telco['MonthlyCharges']
# Out:
# 0       0.115423
# 1       0.385075
# 2       0.354229
# 3       0.239303
# 4       0.521891
#           ...
# 7038    0.662189
# 7039    0.845274
# 7040    0.112935
# 7041    0.558706
# 7042    0.869652
# Name: MonthlyCharges, Length: 7032, dtype: float64

# %%
# TotalCharges : 정규화
totalcharges = np.array(telco.TotalCharges).reshape(-1,1)
scaler = MinMaxScaler()
totalcharges_a = scaler.fit_transform(totalcharges)
telco['TotalCharges'] = totalcharges_a

# %%
telco['TotalCharges']
# Out:
# 0       0.001275
# 1       0.215867
# 2       0.010310
# 3       0.210241
# 4       0.015330
#           ...
# 7038    0.227521
# 7039    0.847461
# 7040    0.037809
# 7041    0.033210
# 7042    0.787641
# Name: TotalCharges, Length: 7032, dtype: float64

# %%
telco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7032 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7032 non-null   object
#  1   SeniorCitizen     7032 non-null   int64
#  2   Partner           7032 non-null   object
#  3   Dependents        7032 non-null   object
#  4   tenure            7032 non-null   float64
#  5   PhoneService      7032 non-null   object
#  6   MultipleLines     7032 non-null   object
#  7   InternetService   7032 non-null   object
#  8   OnlineSecurity    7032 non-null   object
#  9   OnlineBackup      7032 non-null   object
#  10  DeviceProtection  7032 non-null   object
#  11  TechSupport       7032 non-null   object
#  12  StreamingTV       7032 non-null   object
#  13  StreamingMovies   7032 non-null   object
#  14  Contract          7032 non-null   object
#  15  PaperlessBilling  7032 non-null   object
#  16  PaymentMethod     7032 non-null   object
#  17  MonthlyCharges    7032 non-null   float64
#  18  TotalCharges      7032 non-null   float64
#  19  Churn             7032 non-null   int64
# dtypes: float64(3), int64(2), object(15)
# memory usage: 1.1+ MB

# %%
sns.pairplot(telco)

# %%
sns.distplot(telco['tenure'])
# Out:
# <ipython-input-33-8c9b2309891c>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(telco['tenure'])
# <Axes: xlabel='tenure', ylabel='Density'>

# %%
sns.distplot(telco['MonthlyCharges'])
# Out:
# <ipython-input-34-089b2c65c3cf>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(telco['MonthlyCharges'])
# <Axes: xlabel='MonthlyCharges', ylabel='Density'>

# %%
# one-hot_encoding 부분(churn)
telco_dummies = telco.drop('Churn', axis=1)
telco_dummies = pd.get_dummies(telco_dummies)
telco_dummies['Churn'] = telco['Churn']

# %%
telco['Churn']
# Out:
# 0       0
# 1       0
# 2       1
# 3       0
# 4       1
#        ..
# 7038    0
# 7039    0
# 7040    0
# 7041    1
# 7042    0
# Name: Churn, Length: 7032, dtype: int64

# %%
from sklearn.model_selection import train_test_split

data = telco_dummies.drop('Churn', axis=1)
target = telco_dummies.Churn

seed = 1000

X_train_val, X_test, y_train_val, y_test = train_test_split(data,target,random_state=seed)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, random_state=seed)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression().fit(X_train, y_train)

y_pre = model.predict(X_val)

# %%
probs = model.predict_proba(X_val)
y_prob = probs[:,1]

# %%
model_box = pd.DataFrame(columns=['logistic','xgboost','lightgbm','catboost'],
                         index = ['accuracy','precision','recall','f1 score','f1.5 score','f2 score','pr_auc','roc_auc'])

# %%
from sklearn.metrics import f1_score, precision_score, recall_score
from sklearn.metrics import accuracy_score

# %%
def f_score(beta,y_real, y_pred):
    beta = beta
    pr = precision_score(y_real, y_pred)
    re = recall_score(y_real, y_pred)
    score = (1+beta**2)*(pr*re)/((beta**2*pr)+re)
    return score

# %%
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_auc_score

# %%
def evaluate(y_real,y_pred, y_prob):
    acc = accuracy_score(y_real, y_pred)
    pre = precision_score(y_real, y_pred)
    rec = recall_score(y_real, y_pred)
    f1 = f1_score(y_real, y_pred)
    f2 = f_score(1.5,y_real, y_pred)
    f3 = f_score(2,y_real, y_pred)
    auc1 = average_precision_score(y_real, y_prob)
    auc2 = roc_auc_score(y_real, y_prob)
    print('Accuracy : {:.6f}'.format(acc)) #정확도 : 예측이 정답과 얼마나 정확한가
    print('Precision : {:.6f}'.format(pre)) #정밀도 : 예측한 것 중에서 정답의 비율
    print('Recall : {:.6f}'.format(rec)) #재현율 : 정답 중에서 예측한 것의 비율
    print('F1 score : {:.6f}'.format(f1)) #정밀도와 재현율의 (조화)평균 - 정밀도와 재현율이 비슷할수록 높은 점수
    print('F1.5 score : {:.6f}'.format(f2))
    print('F2 score : {:.6f}'.format(f3))
    print('PR curve_auc score : {:.6f}'.format(auc1))
    print('ROC curve_auc score : {:.6f}'.format(auc2))
    print('\nConfusion Matrix : \n {}'.format(confusion_matrix(y_real, y_pred, labels = [1,0]))) # labels를 설정해주지 않으면 순서가 바뀜

    score_list = [acc,pre,rec,f1,f2,f3,auc1,auc2]
    score_box = np.array(score_list)
    return score_box

# %%
def graph_f_score(i,j,k,y_real,y_pred):
    x_range = np.arange(i,j,k)
    score = []
    for kk in x_range:
        score.append(f_score(kk,y_real,y_pred))
    score = np.array(score)
    plt.figure(figsize=(10,5))
    plt.plot(x_range, score,'-o')
    plt.title('F-score by weight')
    plt.xlabel('weight')
    plt.ylabel('f-score')

# %%
from sklearn.metrics import confusion_matrix

# %%
evaluate(y_val,y_pre,y_prob)
# Out:
# Accuracy : 0.796816
# Precision : 0.641447
# Recall : 0.550847
# F1 score : 0.592705
# F1.5 score : 0.575875
# F2 score : 0.566860
# PR curve_auc score : 0.629383
# ROC curve_auc score : 0.833635
#
# Confusion Matrix :
#  [[195 159]
#  [109 856]]
# array([0.79681577, 0.64144737, 0.55084746, 0.59270517, 0.5758746 ,
#        0.56686047, 0.62938339, 0.83363485])

# %%
graph_f_score(0.1,10,0.2, y_val,y_pre)

# %%
def precision_recall_thresholds(y_val, y_prob):
    precisions, recalls, thresholds = precision_recall_curve(y_val, y_prob)
    plt.figure(figsize = (15,5))
    plt.plot(thresholds, recalls[:-1], color = 'red', label = 'recall')
    plt.plot(thresholds, precisions[:-1], color = 'blue', label = 'precision')
    plt.title('thresholds VS recalls VS precisions')
    plt.xlabel('thresholds')
    plt.legend(loc = 'best')

# %%
from sklearn.metrics import precision_recall_curve

# %%
precision_recall_thresholds(y_val, y_prob)

# %%
def plot_pr_curve(y_val, y_prob):
    precisions, recalls, thresholds = precision_recall_curve(y_val, y_prob)
    pr_auc = average_precision_score(y_val, y_prob)
    plt.title('Precision-Recall Curve')
    plt.plot(recalls, precisions, 'b', label = 'AUC = %0.2f' % pr_auc)
    plt.legend(loc = 'lower right')
    b_line = len(y_val[y_val==1]) / len(y_val)
    plt.plot([0, 1], [b_line, b_line], "r--")
    plt.xlim([0, 1])
    plt.ylim([0, 1])
    plt.ylabel('Precision')
    plt.xlabel('Recall')
    plt.show()

# %%
plot_pr_curve(y_val, y_prob)

# %%
# xgb_model = xgb.XGB
import lightgbm as lgb
import xgboost as xgb
# import catboost import CatBoostClassifier, Pool
from sklearn.linear_model import LogisticRegression

# %%
xgb_model = xgb.XGBClassifier(booster='gbtree',
                              objective = 'binary:logistic',
                              eval_metric = 'error',
                              seed = seed)
model = xgb_model.fit(X_train, y_train)
y_pre = model.predict(X_val)

# %%
probs = model.predict_proba(X_val)

# %%
y_prob = probs[:,1]

# %%
evaluate(y_val, y_pre, y_prob)
# Out:
# Accuracy : 0.759666
# Precision : 0.564014
# Recall : 0.460452
# F1 score : 0.506998
# F1.5 score : 0.488024
# F2 score : 0.478006
# PR curve_auc score : 0.601810
# ROC curve_auc score : 0.811920
#
# Confusion Matrix :
#  [[163 191]
#  [126 839]]
# array([0.75966641, 0.56401384, 0.46045198, 0.50699844, 0.48802395,
#        0.47800587, 0.60180962, 0.81192003])

# %%
graph_f_score(0.1,10,0.2,y_val,y_pre)

# %%
precision_recall_thresholds(y_val,y_prob)

# %%
# from sklearn.metrics import plot_roc_curve

# %%
plot_pr_curve(y_val, y_prob)
# plot_roc_curve(y_val, y_prob)

# %%
from sklearn.model_selection import GridSearchCV

# %%
# param_grid = {'booster': ['gbtree'],
#                   'objective' : ['binary:logistic'],
#                   'eval_metric' : ['error'],
#                   'n_estimators':[100],
#                   'max_depth': [3,5,7,9],
#                   'min_child_weight':[1,3,5,7],
#                   'learning_rate' : [0.01,0.05,0.1],
#                   'scale_pos_weight':[1,3,5],
#                   'colsample_bytree':[0.5,0.7,0.9]}

# grid = GridSearchCV(estimator = xgb.XGBClassifier(), param_grid=param_grid, scoring=cri_score, verbose=1, n_jobs=-1, cv=5,)

# grid_result = grid.fit(X_train_val, y_train_val)

# print('best parameter : {}'.format(grid.best_params_))
# print('best score of CV : {:.3f}'.format(grid.best_score_)) # 교차검증의 평균 정확도
# print('best score of test set : {:.3f}'.format(grid.score(X_test,y_test))) # 최적의 매개변수와 전체 train 데이터로 만든 모델로 평가한 점수

# y_pred = grid_result.predict(X_test)

# probs = grid_resu
# fig, ax = plt.subplots(3,1,figsize = (12,25))
# for i, type_ in enumerate(['weight','cover','gain']):
#     xgb.plot_importance(grid_result.best_estimator_,importance_type = type_, ax=ax[i])
#     ax[i].set_title('Feature importance with '+type_)

# %%
#Lightgbm 시도
lgb_model = lgb.LGBMClassifier(booster = 'gbtree',
                               objective = 'binary',
                               seed = seed)

model = lgb_model.fit(X_train, y_train)
y_pre = model.predict(X_val)
# Out:
# [LightGBM] [Warning] Unknown parameter: booster
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: booster
# [LightGBM] [Info] Number of positive: 1062, number of negative: 2893
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.001127 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 666
# [LightGBM] [Info] Number of data points in the train set: 3955, number of used features: 45
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.268521 -> initscore=-1.002140
# [LightGBM] [Info] Start training from score -1.002140
# [LightGBM] [Warning] Unknown parameter: booster

# %%
probs = model.predict_proba(X_val)
y_prob = probs[:,1]
# Out:
# [LightGBM] [Warning] Unknown parameter: booster

# %%
evaluate(y_val, y_pre, y_prob)
# Out:
# Accuracy : 0.780136
# Precision : 0.602564
# Recall : 0.531073
# F1 score : 0.564565
# F1.5 score : 0.551195
# F2 score : 0.543981
# PR curve_auc score : 0.635400
# ROC curve_auc score : 0.830241
#
# Confusion Matrix :
#  [[188 166]
#  [124 841]]
# array([0.78013647, 0.6025641 , 0.53107345, 0.56456456, 0.55119531,
#        0.54398148, 0.63540029, 0.83024063])

# %%
graph_f_score(0.1,10,0.2,y_val,y_pre)

# %%
precision_recall_thresholds(y_val, y_prob)

# %%
plot_pr_curve(y_val, y_prob)

# %%
#DecisionTree
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import graphviz
from IPython.display import display
import os

# %%
def plot_decision_tree(columns, maximum_depth, criterion_type, split_type):
    #preparing data
    columns = ['tenure','MonthlyCharges','TotalCharges']
    dt_train_val = X_train_val[columns]
    dt_test = X_test[columns]

    #modeling
    dt_classifier = DecisionTreeClassifier(max_depth = maximum_depth, splitter = split_type, criterion = criterion_type)
    model = dt_classifier.fit(dt_train_val, y_train_val)

    #evaluation
    y_pre = model.predict(dt_test)
    probs = model.predict_proba(dt_test)
    y_prob = probs[:,1]
    evaluate(y_test,y_pre,y_prob)

    #plot decision tree
    #그래프 저장용 텍스트 파일(.dot)파일 생성
    graph = export_graphviz(dt_classifier, out_file = "tree.dot", feature_names = columns, class_names= ['Not Churn', 'Churn'], filled = True)

    #파일 읽어오기
    with open("tree.dot") as f:
        dot_graph = f.read()

    display(graphviz.Source(dot_graph))

    # 특성중요도
    plt.figure(figsize = (10,5))
    plt.barh(range(3),model.feature_importances_, align='center')
    plt.title('Feature Importances')
    plt.yticks(np.arange(3),columns)
    plt.ylabel('features')
    plt.xlabel('importances')

# %%
plot_decision_tree(col,4,'entropy','best')
# Out:
# Accuracy : 0.792947
# Precision : 0.653979
# Recall : 0.417219
# F1 score : 0.509434
# F1.5 score : 0.469520
# F2 score : 0.449786
# PR curve_auc score : 0.567512
# ROC curve_auc score : 0.805723
#
# Confusion Matrix :
#  [[ 189  264]
#  [ 100 1205]]

# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings(action='ignore')

#Visulization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

#preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

#Machine Learning
import lightgbm as lgb
import xgboost as xgb
# import catboost as cb
from sklearn.linear_model import LogisticRegression

#Evaluation
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score, roc_auc_score, average_precision_score
from sklearn.metrics import confusion_matrix, precision_recall_curve, roc_curve

#HyperParameters
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# F2 score for gridSearchCV
from sklearn.metrics import fbeta_score
from sklearn.metrics import make_scorer

# %%
param_grid = {'booster': ['gbtree'],
                  'objective' : ['binary:logistic'],
                  'eval_metric' : ['error'],
                  'n_estimators':[100],
                  'max_depth': [3,5,7,9],
                  'min_child_weight':[1,3,5,7],
                  'learning_rate' : [0.01,0.05,0.1],
                  'scale_pos_weight':[1,3,5],
                  'colsample_bytree':[0.5,0.7,0.9]}

grid = GridSearchCV(estimator = xgb.XGBClassifier(), param_grid=param_grid, verbose=1, n_jobs=-1, cv=5)

grid_result = grid.fit(X_train_val, y_train_val)

print('best parameter : {}'.format(grid.best_params_))
print('best score of CV : {:.3f}'.format(grid.best_score_)) # 교차검증의 평균 정확도
print('best score of test set : {:.3f}'.format(grid.score(X_test,y_test))) # 최적의 매개변수와 전체 train 데이터로 만든 모델로 평가한 점수
# Out:
# Fitting 5 folds for each of 432 candidates, totalling 2160 fits
# best parameter : {'booster': 'gbtree', 'colsample_bytree': 0.5, 'eval_metric': 'error', 'learning_rate': 0.05, 'max_depth': 3, 'min_child_weight': 1, 'n_estimators': 100, 'objective': 'binary:logistic', 'scale_pos_weight': 1}
# best score of CV : 0.801
# best score of test set : 0.821

# %%
y_pred = grid_result.predict(X_test)

probs = grid_result.predict_proba(X_test)
y_prob = probs[:,1]

model_box['xgboost'] = evaluate(y_test, y_pred, y_prob)
# Out:
# Accuracy : 0.820819
# Precision : 0.711656
# Recall : 0.512141
# F1 score : 0.595635
# F1.5 score : 0.560491
# F2 score : 0.542563
# PR curve_auc score : 0.667096
# ROC curve_auc score : 0.857969
#
# Confusion Matrix :
#  [[ 232  221]
#  [  94 1211]]

# %%
fig, ax = plt.subplots(3,1,figsize = (12,25))
for i, type_ in enumerate(['weight','cover','gain']):
    xgb.plot_importance(grid_result.best_estimator_,importance_type = type_, ax=ax[i])
    ax[i].set_title('Feature importance with '+type_)

# %%
# lightgbm
param_grid = {'booster': ['gbtree'],
             'objective' : ['binary'],
             'learning_rate':[0.01,0.05,0.1],
              'num_leaves' : [12,15,18],
              'feature_fraction' : [0.5,0.7,0.9],
              'subsample' : [0.5,0.7,0.9],
              'min_child_weight':[1,3,5,7]
             }

grid = GridSearchCV(estimator = lgb.LGBMClassifier(), param_grid=param_grid, verbose=1, n_jobs=-1, cv=5,)

grid_result = grid.fit(X_train_val, y_train_val)

print('best parameter : {}'.format(grid.best_params_))
print('best score of CV : {:.3f}'.format(grid.best_score_)) # 교차검증의 평균 정확도
print('best score of test set : {:.3f}'.format(grid.score(X_test,y_test))) # 최적의 매개변수와 전체 train 데이터로 만든 모델로 평가한 점수
# Out:
# Fitting 5 folds for each of 324 candidates, totalling 1620 fits
# [LightGBM] [Warning] Unknown parameter: booster
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Warning] Unknown parameter: booster
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Info] Number of positive: 1416, number of negative: 3858
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000735 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 666
# [LightGBM] [Info] Number of data points in the train set: 5274, number of used features: 45
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.268487 -> initscore=-1.002313
# [LightGBM] [Info] Start training from score -1.002313
# best parameter : {'booster': 'gbtree', 'feature_fraction': 0.9, 'learning_rate': 0.05, 'min_child_weight': 1, 'num_leaves': 12, 'objective': 'binary', 'subsample': 0.5}
# best score of CV : 0.802
# [LightGBM] [Warning] Unknown parameter: booster
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# best score of test set : 0.818

# %%
# 테스트
y_pred = grid_result.predict(X_test)

probs = grid_result.predict_proba(X_test)
y_prob = probs[:,1]

model_box['lightgbm'] = evaluate(y_test, y_pred, y_prob)
# Out:
# [LightGBM] [Warning] Unknown parameter: booster
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# [LightGBM] [Warning] Unknown parameter: booster
# [LightGBM] [Warning] feature_fraction is set=0.9, colsample_bytree=1.0 will be ignored. Current value: feature_fraction=0.9
# Accuracy : 0.817975
# Precision : 0.695015
# Recall : 0.523179
# F1 score : 0.596977
# F1.5 score : 0.566256
# F2 score : 0.550395
# PR curve_auc score : 0.659182
# ROC curve_auc score : 0.855429
#
# Confusion Matrix :
#  [[ 237  216]
#  [ 104 1201]]

# %%
fig, ax = plt.subplots(1,1,figsize = (12,10))
lgb.plot_importance(grid_result.best_estimator_, ax=ax)
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %%
model_box['xgboost'] = evaluate(y_test, y_pred, y_prob)
model_box['lightgbm'] = evaluate(y_test, y_pred, y_prob)
model_box['logistic'] = evaluate(y_test, y_pred, y_prob)
# Out:
# Accuracy : 0.817975
# Precision : 0.695015
# Recall : 0.523179
# F1 score : 0.596977
# F1.5 score : 0.566256
# F2 score : 0.550395
# PR curve_auc score : 0.659182
# ROC curve_auc score : 0.855429
#
# Confusion Matrix :
#  [[ 237  216]
#  [ 104 1201]]
# Accuracy : 0.817975
# Precision : 0.695015
# Recall : 0.523179
# F1 score : 0.596977
# F1.5 score : 0.566256
# F2 score : 0.550395
# PR curve_auc score : 0.659182
# ROC curve_auc score : 0.855429
#
# Confusion Matrix :
#  [[ 237  216]
#  [ 104 1201]]
# Accuracy : 0.817975
# Precision : 0.695015
# Recall : 0.523179
# F1 score : 0.596977
# F1.5 score : 0.566256
# F2 score : 0.550395
# PR curve_auc score : 0.659182
# ROC curve_auc score : 0.855429
#
# Confusion Matrix :
#  [[ 237  216]
#  [ 104 1201]]

# %%
# 최종도출
model_box
# Out:
#             logistic   xgboost  lightgbm catboost
# accuracy    0.817975  0.817975  0.817975      NaN
# precision   0.695015  0.695015  0.695015      NaN
# recall      0.523179  0.523179  0.523179      NaN
# f1 score    0.596977  0.596977  0.596977      NaN
# f1.5 score  0.566256  0.566256  0.566256      NaN
# f2 score    0.550395  0.550395  0.550395      NaN
# pr_auc      0.659182  0.659182  0.659182      NaN
# roc_auc     0.855429  0.855429  0.855429      NaN
